# %% [markdown]
# Imported libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Kaggle Dataset

# %%
# Kaggle: sample Samsung(heart rate) data
data = pd.read_csv(r'C:\Users\S2225244\Desktop\2023 SUMMER PROJECT\code\kaggle\aw_fb_data.csv') 

print(data.columns)
# Out:
# Index(['Unnamed: 0', 'X1', 'age', 'gender', 'height', 'weight', 'steps',
#        'hear_rate', 'calories', 'distance', 'entropy_heart', 'entropy_setps',
#        'resting_heart', 'corr_heart_steps', 'norm_heart', 'intensity_karvonen',
#        'sd_norm_heart', 'steps_times_distance', 'device', 'activity'],
#       dtype='object')

# %% [markdown]
# Heart Rate Data Time Points - Apple Watch

# %%
y = data['hear_rate'][147:220]
x = range(len(y)) # Generate new x-axis values starting from 0

fig, axs = plt.subplots(3, 2)
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 1')

y = data['hear_rate'][746:824]
x = range(len(y)) 
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 2')

y = data['hear_rate'][974:1053]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 3')

y = data['hear_rate'][1053:1130]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 4')

y = data['hear_rate'][1353:1428]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 5')

y = data['hear_rate'][1502:1575]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 6')

fig.suptitle("Heart Rate Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'Number of beats per minute', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(3, 2)

y = data['hear_rate'][1575:1643]
x = range(len(y))
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 7')

y = data['hear_rate'][1644:1717]
x = range(len(y))
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 8')

y = data['hear_rate'][1717:1788]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 9')

y = data['hear_rate'][1788:1861]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 10')

y = data['hear_rate'][1861:1950]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 11')

y = data['hear_rate'][1950:2028]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 12')

fig.suptitle("Heart Rate Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'Number of beats per minute', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(3, 2)

y = data['hear_rate'][2103:2167]
x = range(len(y))
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 13')

y = data['hear_rate'][2167:2246]
x = range(len(y))
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 14')

y = data['hear_rate'][2246:2319]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 15')

y = data['hear_rate'][2319:2392]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 16')

y = data['hear_rate'][2463:2535]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 17')

y = data['hear_rate'][2535:2607]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 18')

fig.suptitle("Heart Rate Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'Number of beats per minute', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(3, 2)

y = data['hear_rate'][2607:2680]
x = range(len(y))
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 19')

y = data['hear_rate'][2680:2757]
x = range(len(y))
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 20')

y = data['hear_rate'][2757:2832]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 21')

y = data['hear_rate'][2832:2904]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 22')

y = data['hear_rate'][2904:2978]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 23')

y = data['hear_rate'][2978:3056]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 24')

fig.suptitle("Heart Rate Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'Number of beats per minute', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(3, 2)

y = data['hear_rate'][3056:3128]
x = range(len(y))
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 25')

y = data['hear_rate'][3128:3200]
x = range(len(y))
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 26')

y = data['hear_rate'][3200:3276]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 27')

y = data['hear_rate'][3276:3352]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 28')

y = data['hear_rate'][3352:3429]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 29')

y = data['hear_rate'][3429:3510]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 30')

fig.suptitle("Heart Rate Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'Number of beats per minute', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %% [markdown]
# Heart Rate

# %%
# Convert column values to a float
Heart_Rate = data['hear_rate'][0:3656].astype(float)

print(Heart_Rate)
# Out:
# 0        78.531302
# 1        78.453390
# 2        78.540825
# 3        78.628260
# 4        78.715695
#            ...
# 3651    157.250000
# 3652    157.307692
# 3653    156.250000
# 3654    158.090909
# 3655    157.230769
# Name: hear_rate, Length: 3656, dtype: float64

# %% [markdown]
# RR Interval

# %%
# (rr interval or) time interval in milliseconds
rr_interval = 60000 / Heart_Rate

#differences between consecutive rr intervals, convert the numbers from negative to positive
hrv = [abs(num) for num in(np.diff(rr_interval))]

print(rr_interval)
print(hrv)
# Out:
# 0       764.026550
# 1       764.785305
# 2       763.933915
# 3       763.084419
# 4       762.236810
#            ...
# 3651    381.558029
# 3652    381.418093
# 3653    384.000000
# 3654    379.528465
# 3655    381.604697
# Name: hear_rate, Length: 3656, dtype: float64
# ...

# %% [markdown]
# RR plot

# %%
y = rr_interval[147:220]
x = range(len(y)) # Generate new x-axis values starting from 0

fig, axs = plt.subplots(3, 2)
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 1')

y = rr_interval[746:824]
x = range(len(y)) 
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 2')

y = rr_interval[974:1053]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 3')

y = rr_interval[1053:1130]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 4')

y = rr_interval[1353:1428]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 5')

y = rr_interval[1502:1575]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 6')

fig.suptitle("RR Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'RR (ms)', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(3, 2)

y = rr_interval[1575:1643]
x = range(len(y))
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 7')

y = rr_interval[1644:1717]
x = range(len(y))
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 8')

y = rr_interval[1717:1788]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 9')

y = rr_interval[1788:1861]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 10')

y = rr_interval[1861:1950]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 11')

y = rr_interval[1950:2028]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 12')

fig.suptitle("RR Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'RR (ms)', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(3, 2)

y = rr_interval[2103:2167]
x = range(len(y))
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 13')

y = rr_interval[2167:2246]
x = range(len(y))
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 14')

y = rr_interval[2246:2319]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 15')

y = rr_interval[2319:2392]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 16')

y = rr_interval[2463:2535]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 17')

y = rr_interval[2535:2607]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 18')

fig.suptitle("RR Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'RR (ms)', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(3, 2)

y = rr_interval[2607:2680]
x = range(len(y))
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 19')

y = rr_interval[2680:2757]
x = range(len(y))
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 20')

y = rr_interval[2757:2832]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 21')

y = rr_interval[2832:2904]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 22')

y = rr_interval[2904:2978]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 23')

y = rr_interval[2978:3056]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 24')

fig.suptitle("RR Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'RR (ms)', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(3, 2)

y = rr_interval[3056:3128]
x = range(len(y))
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 25')

y = rr_interval[3128:3200]
x = range(len(y))
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 26')

y = rr_interval[3200:3276]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 27')

y = rr_interval[3276:3352]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 28')

y = rr_interval[3352:3429]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 29')

y = rr_interval[3429:3510]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 30')

fig.suptitle("RR Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'RR (ms)', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %% [markdown]
# HRV plot

# %%
y = hrv[147:220]
x = range(len(y)) # Generate new x-axis values starting from 0

fig, axs = plt.subplots(3, 2)
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 1')

y = hrv[746:824]
x = range(len(y)) 
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 2')

y = hrv[974:1053]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 3')

y = hrv[1053:1130]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 4')

y = hrv[1353:1428]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 5')

y = hrv[1502:1575]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 6')

fig.suptitle("HRV Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'HRV (ms)', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(3, 2)

y = hrv[1575:1643]
x = range(len(y))
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 7')

y = hrv[1644:1717]
x = range(len(y))
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 8')

y = hrv[1717:1788]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 9')

y = hrv[1788:1861]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 10')

y = hrv[1861:1950]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 11')

y = hrv[1950:2028]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 12')

fig.suptitle("HRV Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'HRV (ms)', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(3, 2)

y = hrv[2103:2167]
x = range(len(y))
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 13')

y = hrv[2167:2246]
x = range(len(y))
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 14')

y = hrv[2246:2319]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 15')

y = hrv[2319:2392]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 16')

y = hrv[2463:2535]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 17')

y = hrv[2535:2607]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 18')

fig.suptitle("HRV Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'HRV (ms)', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(3, 2)

y = hrv[2607:2680]
x = range(len(y))
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 19')

y = hrv[2680:2757]
x = range(len(y))
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 20')

y = hrv[2757:2832]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 21')

y = hrv[2832:2904]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 22')

y = hrv[2904:2978]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 23')

y = hrv[2978:3056]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 24')

fig.suptitle("HRV Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'HRV (ms)', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(3, 2)

y = hrv[3056:3128]
x = range(len(y))
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Participant 25')

y = hrv[3128:3200]
x = range(len(y))
axs[0, 1].plot(x,y)
axs[0, 1].set_title('Participant 26')

y = hrv[3200:3276]
x = range(len(y))
axs[1, 0].plot(x,y)
axs[1, 0].set_title('Participant 27')

y = hrv[3276:3352]
x = range(len(y))
axs[1, 1].plot(x,y)
axs[1, 1].set_title('Participant 28')

y = rr_interval[3352:3429]
x = range(len(y))
axs[2, 0].plot(x,y)
axs[2, 0].set_title('Participant 29')

y = rr_interval[3429:3510]
x = range(len(y))
axs[2, 1].plot(x,y)
axs[2, 1].set_title('Participant 30')

fig.suptitle("HRV Data - Apple Watch")  ## Set a single title for all subplots
fig.text(0.5, 0, 'Time points (minutes)', ha='center')  ## Set a single x-axis and y-axis title for all subplots
fig.text(0, 0.5, 'HRV (ms)', va='center', rotation='vertical')
plt.tight_layout()

plt.show()

# %% [markdown]
# Time Domain Analysis

# %% [markdown]
# 1.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[147:220])
# Out:
# {'Mean HR (beats/min)': 101.67080385607542,
#  'STD HR (beats/min)': 21.8524645698053,
#  'Min HR (beats/min)': 73.25,
#  'Max HR (beats/min)': 153.538461538462}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[147:220])
# Out:
# {'Mean RR (ms)': 615.1930772921693,
#  'STD RR/SDNN (ms)': 118.64396235465365,
#  'RMSSD (ms)': 48.24344205978034,
#  'NNxx': 13,
#  'pNNxx (%)': 17.80821917808219}

# %% [markdown]
# 2.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[746:824])
# Out:
# {'Mean HR (beats/min)': 58.767877146927134,
#  'STD HR (beats/min)': 11.473770469421547,
#  'Min HR (beats/min)': 38.5,
#  'Max HR (beats/min)': 85.0}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[746:824])
# Out:
# {'Mean RR (ms)': 1061.2460528168372,
#  'STD RR/SDNN (ms)': 211.09418890719212,
#  'RMSSD (ms)': 35.732168405597065,
#  'NNxx': 10,
#  'pNNxx (%)': 12.820512820512821}

# %% [markdown]
# 3.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[974:1053])
# Out:
# {'Mean HR (beats/min)': 66.65325399085795,
#  'STD HR (beats/min)': 18.099583944978242,
#  'Min HR (beats/min)': 33.0,
#  'Max HR (beats/min)': 91.5}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[974:1053])
# Out:
# {'Mean RR (ms)': 991.7596707666067,
#  'STD RR/SDNN (ms)': 351.12056363415905,
#  'RMSSD (ms)': 125.8997651413236,
#  'NNxx': 9,
#  'pNNxx (%)': 11.39240506329114}

# %% [markdown]
# 4.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[1053:1130])
# Out:
# {'Mean HR (beats/min)': 74.3381237476809,
#  'STD HR (beats/min)': 10.932733738541572,
#  'Min HR (beats/min)': 54.0,
#  'Max HR (beats/min)': 117.333333333333}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[1053:1130])
# Out:
# {'Mean RR (ms)': 824.8910200298551,
#  'STD RR/SDNN (ms)': 123.62381756840975,
#  'RMSSD (ms)': 51.04868958060285,
#  'NNxx': 4,
#  'pNNxx (%)': 5.194805194805195}

# %% [markdown]
# 5.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[1353:1428])
# Out:
# {'Mean HR (beats/min)': 102.25832198124098,
#  'STD HR (beats/min)': 37.14427741817686,
#  'Min HR (beats/min)': 56.0,
#  'Max HR (beats/min)': 179.416666666667}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[1353:1428])
# Out:
# {'Mean RR (ms)': 664.069846375241,
#  'STD RR/SDNN (ms)': 222.7191897943732,
#  'RMSSD (ms)': 31.55569398663677,
#  'NNxx': 3,
#  'pNNxx (%)': 4.0}

# %% [markdown]
# 6.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[1502:1575])
# Out:
# {'Mean HR (beats/min)': 112.83747523300516,
#  'STD HR (beats/min)': 14.432570007826962,
#  'Min HR (beats/min)': 78.4533902777777,
#  'Max HR (beats/min)': 145.636363636364}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[1502:1575])
# Out:
# {'Mean RR (ms)': 540.4715079374345,
#  'STD RR/SDNN (ms)': 69.53825260372388,
#  'RMSSD (ms)': 25.22768818260724,
#  'NNxx': 4,
#  'pNNxx (%)': 5.47945205479452}

# %% [markdown]
# 7.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[1575:1643])
# Out:
# {'Mean HR (beats/min)': 92.2018295801217,
#  'STD HR (beats/min)': 34.95386173068945,
#  'Min HR (beats/min)': 63.0,
#  'Max HR (beats/min)': 184.916666666667}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[1575:1643])
# Out:
# {'Mean RR (ms)': 719.7674461685172,
#  'STD RR/SDNN (ms)': 188.30157252907782,
#  'RMSSD (ms)': 44.70492926548219,
#  'NNxx': 7,
#  'pNNxx (%)': 10.294117647058824}

# %% [markdown]
# 8.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[1644:1717])
# Out:
# {'Mean HR (beats/min)': 107.02819770206962,
#  'STD HR (beats/min)': 29.502492042930516,
#  'Min HR (beats/min)': 63.0,
#  'Max HR (beats/min)': 175.818181818182}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[1644:1717])
# Out:
# {'Mean RR (ms)': 599.9068752173791,
#  'STD RR/SDNN (ms)': 148.23957526257036,
#  'RMSSD (ms)': 59.946466197074095,
#  'NNxx': 21,
#  'pNNxx (%)': 28.767123287671232}

# %% [markdown]
# 9.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[1717:1788])
# Out:
# {'Mean HR (beats/min)': 81.0638211602951,
#  'STD HR (beats/min)': 15.627124544655754,
#  'Min HR (beats/min)': 57.0,
#  'Max HR (beats/min)': 113.0}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[1717:1788])
# Out:
# {'Mean RR (ms)': 767.855760072557,
#  'STD RR/SDNN (ms)': 146.48550781828294,
#  'RMSSD (ms)': 73.04705082495394,
#  'NNxx': 24,
#  'pNNxx (%)': 33.80281690140845}

# %% [markdown]
# 10.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[1788:1861])
# Out:
# {'Mean HR (beats/min)': 109.33531450193642,
#  'STD HR (beats/min)': 35.141092501845826,
#  'Min HR (beats/min)': 76.0,
#  'Max HR (beats/min)': 186.583333333333}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[1788:1861])
# Out:
# {'Mean RR (ms)': 594.5969856320124,
#  'STD RR/SDNN (ms)': 146.11265459165674,
#  'RMSSD (ms)': 35.368965083796155,
#  'NNxx': 8,
#  'pNNxx (%)': 10.95890410958904}

# %% [markdown]
# 11.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[1861:1950])
# Out:
# {'Mean HR (beats/min)': 79.29457058175906,
#  'STD HR (beats/min)': 9.732529904259687,
#  'Min HR (beats/min)': 60.0,
#  'Max HR (beats/min)': 116.692307692308}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[1861:1950])
# Out:
# {'Mean RR (ms)': 767.2919369735868,
#  'STD RR/SDNN (ms)': 88.47830630257519,
#  'RMSSD (ms)': 29.176507283330263,
#  'NNxx': 9,
#  'pNNxx (%)': 10.112359550561798}

# %% [markdown]
# 12.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[1950:2028])
# Out:
# {'Mean HR (beats/min)': 93.00985233164272,
#  'STD HR (beats/min)': 32.10759700052383,
#  'Min HR (beats/min)': 49.0,
#  'Max HR (beats/min)': 160.833333333333}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[1950:2028])
# Out:
# {'Mean RR (ms)': 719.2117690714978,
#  'STD RR/SDNN (ms)': 225.29775323430212,
#  'RMSSD (ms)': 78.19887885505825,
#  'NNxx': 15,
#  'pNNxx (%)': 19.23076923076923}

# %% [markdown]
# 13.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[2103:2167])
# Out:
# {'Mean HR (beats/min)': 73.53977713448657,
#  'STD HR (beats/min)': 20.659627609900106,
#  'Min HR (beats/min)': 50.0,
#  'Max HR (beats/min)': 127.375}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[2103:2167])
# Out:
# {'Mean RR (ms)': 874.159490988925,
#  'STD RR/SDNN (ms)': 214.3034862386374,
#  'RMSSD (ms)': 77.52255187531439,
#  'NNxx': 15,
#  'pNNxx (%)': 23.4375}

# %% [markdown]
# 14.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[2167:2246])
# Out:
# {'Mean HR (beats/min)': 104.49728671650084,
#  'STD HR (beats/min)': 22.88656337489581,
#  'Min HR (beats/min)': 78.4533902777777,
#  'Max HR (beats/min)': 157.0}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[2167:2246])
# Out:
# {'Mean RR (ms)': 598.9581801619947,
#  'STD RR/SDNN (ms)': 115.23205439327172,
#  'RMSSD (ms)': 29.54599387105657,
#  'NNxx': 3,
#  'pNNxx (%)': 3.7974683544303796}

# %% [markdown]
# 15.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[2246:2319])
# Out:
# {'Mean HR (beats/min)': 104.78431669557612,
#  'STD HR (beats/min)': 23.32756875476393,
#  'Min HR (beats/min)': 72.6666666666667,
#  'Max HR (beats/min)': 161.833333333333}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[2246:2319])
# Out:
# {'Mean RR (ms)': 598.5985468684047,
#  'STD RR/SDNN (ms)': 119.66979999825152,
#  'RMSSD (ms)': 41.031015024686155,
#  'NNxx': 9,
#  'pNNxx (%)': 12.32876712328767}

# %% [markdown]
# 16.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[2319:2392])
# Out:
# {'Mean HR (beats/min)': 106.450611434969,
#  'STD HR (beats/min)': 18.143943997903907,
#  'Min HR (beats/min)': 61.0,
#  'Max HR (beats/min)': 140.454545454545}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[2319:2392])
# Out:
# {'Mean RR (ms)': 581.7871282203356,
#  'STD RR/SDNN (ms)': 108.7724853609763,
#  'RMSSD (ms)': 50.68613792262362,
#  'NNxx': 10,
#  'pNNxx (%)': 13.698630136986301}

# %% [markdown]
# 17.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[2463:2535])
# Out:
# {'Mean HR (beats/min)': 91.64000661025898,
#  'STD HR (beats/min)': 23.920361108708505,
#  'Min HR (beats/min)': 63.4615384615385,
#  'Max HR (beats/min)': 193.5}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[2463:2535])
# Out:
# {'Mean RR (ms)': 693.7459003942624,
#  'STD RR/SDNN (ms)': 157.42241772259584,
#  'RMSSD (ms)': 78.45683065238,
#  'NNxx': 17,
#  'pNNxx (%)': 23.61111111111111}

# %% [markdown]
# 18.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[2535:2607])
# Out:
# {'Mean HR (beats/min)': 96.09722121179361,
#  'STD HR (beats/min)': 23.440228399554723,
#  'Min HR (beats/min)': 59.3333333333333,
#  'Max HR (beats/min)': 150.75}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[2535:2607])
# Out:
# {'Mean RR (ms)': 657.8375114799832,
#  'STD RR/SDNN (ms)': 142.89637774744494,
#  'RMSSD (ms)': 47.25285452523223,
#  'NNxx': 6,
#  'pNNxx (%)': 8.333333333333334}

# %% [markdown]
# 19.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[2607:2680])
# Out:
# {'Mean HR (beats/min)': 99.31495331871328,
#  'STD HR (beats/min)': 25.549051593758225,
#  'Min HR (beats/min)': 70.0,
#  'Max HR (beats/min)': 172.0}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[2607:2680])
# Out:
# {'Mean RR (ms)': 636.4103722690904,
#  'STD RR/SDNN (ms)': 130.1541279135829,
#  'RMSSD (ms)': 52.92917217338365,
#  'NNxx': 14,
#  'pNNxx (%)': 19.17808219178082}

# %% [markdown]
# 20.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[2680:2757])
# Out:
# {'Mean HR (beats/min)': 80.61017597802632,
#  'STD HR (beats/min)': 29.81650067324189,
#  'Min HR (beats/min)': 56.0,
#  'Max HR (beats/min)': 150.5}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[2680:2757])
# Out:
# {'Mean RR (ms)': 828.6596646797645,
#  'STD RR/SDNN (ms)': 234.75566738788544,
#  'RMSSD (ms)': 50.50610088834687,
#  'NNxx': 8,
#  'pNNxx (%)': 10.38961038961039}

# %% [markdown]
# 21.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[2757:2832])
# Out:
# {'Mean HR (beats/min)': 117.47552449206349,
#  'STD HR (beats/min)': 28.78789616811522,
#  'Min HR (beats/min)': 73.0,
#  'Max HR (beats/min)': 194.333333333333}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[2757:2832])
# Out:
# {'Mean RR (ms)': 540.0535996267856,
#  'STD RR/SDNN (ms)': 125.44336504104886,
#  'RMSSD (ms)': 38.08305148937891,
#  'NNxx': 9,
#  'pNNxx (%)': 12.0}

# %% [markdown]
# 22.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[2832:2904])
# Out:
# {'Mean HR (beats/min)': 106.76901767055284,
#  'STD HR (beats/min)': 21.059030949648665,
#  'Min HR (beats/min)': 47.0,
#  'Max HR (beats/min)': 169.625}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[2832:2904])
# Out:
# {'Mean RR (ms)': 583.6436654420111,
#  'STD RR/SDNN (ms)': 121.99897418747777,
#  'RMSSD (ms)': 109.01377232519738,
#  'NNxx': 13,
#  'pNNxx (%)': 18.055555555555557}

# %% [markdown]
# 23.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[2904:2974])
# Out:
# {'Mean HR (beats/min)': 105.41896124303271,
#  'STD HR (beats/min)': 23.397897769362064,
#  'Min HR (beats/min)': 72.0,
#  'Max HR (beats/min)': 156.363636363636}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[2904:2974])
# Out:
# {'Mean RR (ms)': 595.578381351752,
#  'STD RR/SDNN (ms)': 121.97703301154719,
#  'RMSSD (ms)': 38.87103001329489,
#  'NNxx': 16,
#  'pNNxx (%)': 22.857142857142858}

# %% [markdown]
# 24.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[2978:3056])
# Out:
# {'Mean HR (beats/min)': 115.20255649869185,
#  'STD HR (beats/min)': 25.49538196148405,
#  'Min HR (beats/min)': 78.4533902777777,
#  'Max HR (beats/min)': 170.538461538462}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[2978:3056])
# Out:
# {'Mean RR (ms)': 543.7926233349176,
#  'STD RR/SDNN (ms)': 105.84233590195657,
#  'RMSSD (ms)': 33.68455805628171,
#  'NNxx': 6,
#  'pNNxx (%)': 7.6923076923076925}

# %% [markdown]
# 25.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[3056:3128])
# Out:
# {'Mean HR (beats/min)': 91.125746076069,
#  'STD HR (beats/min)': 25.082656012638918,
#  'Min HR (beats/min)': 57.75,
#  'Max HR (beats/min)': 160.4}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[3056:3128])
# Out:
# {'Mean RR (ms)': 704.6583977886569,
#  'STD RR/SDNN (ms)': 175.03276298746056,
#  'RMSSD (ms)': 65.03107082144285,
#  'NNxx': 12,
#  'pNNxx (%)': 16.666666666666668}

# %% [markdown]
# 26.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[3128:3200])
# Out:
# {'Mean HR (beats/min)': 106.94725986389193,
#  'STD HR (beats/min)': 31.752497251812414,
#  'Min HR (beats/min)': 61.0,
#  'Max HR (beats/min)': 168.857142857143}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[3128:3200])
# Out:
# {'Mean RR (ms)': 608.1912016012569,
#  'STD RR/SDNN (ms)': 164.33207972864167,
#  'RMSSD (ms)': 43.29338332891292,
#  'NNxx': 3,
#  'pNNxx (%)': 4.166666666666667}

# %% [markdown]
# 27.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[3200:3276])
# Out:
# {'Mean HR (beats/min)': 113.84420021228772,
#  'STD HR (beats/min)': 28.47895012497739,
#  'Min HR (beats/min)': 78.5313023809524,
#  'Max HR (beats/min)': 173.0}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[3200:3276])
# Out:
# {'Mean RR (ms)': 556.9717048057305,
#  'STD RR/SDNN (ms)': 121.84282674858643,
#  'RMSSD (ms)': 29.398789213843976,
#  'NNxx': 6,
#  'pNNxx (%)': 7.894736842105263}

# %% [markdown]
# 28.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[3276:3352])
# Out:
# {'Mean HR (beats/min)': 90.97278969447947,
#  'STD HR (beats/min)': 35.224560753885775,
#  'Min HR (beats/min)': 57.0,
#  'Max HR (beats/min)': 153.444444444444}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[3276:3352])
# Out:
# {'Mean RR (ms)': 749.2218453844789,
#  'STD RR/SDNN (ms)': 235.93013537109653,
#  'RMSSD (ms)': 65.43683963716659,
#  'NNxx': 17,
#  'pNNxx (%)': 22.36842105263158}

# %% [markdown]
# 29.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[3352:3429])
# Out:
# {'Mean HR (beats/min)': 89.05132114380929,
#  'STD HR (beats/min)': 18.234846453460456,
#  'Min HR (beats/min)': 60.0,
#  'Max HR (beats/min)': 142.0}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[3352:3429])
# Out:
# {'Mean RR (ms)': 700.6193418124983,
#  'STD RR/SDNN (ms)': 134.65892293473095,
#  'RMSSD (ms)': 52.80126801472767,
#  'NNxx': 17,
#  'pNNxx (%)': 22.07792207792208}

# %% [markdown]
# 30.

# %%
def timedomain(hr):   
    results = {}      
   
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    
    return results

timedomain(Heart_Rate[3429:3510])
# Out:
# {'Mean HR (beats/min)': 121.67257026414948,
#  'STD HR (beats/min)': 30.56779504299506,
#  'Min HR (beats/min)': 75.1818181818182,
#  'Max HR (beats/min)': 177.75}

# %%
def timedomain(rr):   #RR interval of a heartbeat in milliseconds
    results = {}      
   
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)  #Standard Deviation of NN intervals
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))   #root mean square of successive differences between RR intervals
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1   #calculates the number of pairs of successive RR intervals that differ by more than 50 milliseconds
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)   #calculates the percentage of pairs of successive RR intervals that differ by more than 50 milliseconds relative to the total number of RR intervals
    return results

timedomain(rr_interval[3429:3510])
# Out:
# {'Mean RR (ms)': 526.0280933338811,
#  'STD RR/SDNN (ms)': 134.91427200484713,
#  'RMSSD (ms)': 37.54828810933425,
#  'NNxx': 6,
#  'pNNxx (%)': 7.407407407407407}

# %% [markdown]
# plots 2.0

# %%
y1 = data['hear_rate'][147:220]
x1 = range(len(y1)) # Generate new x-axis values starting from 0
y2 = rr_interval[147:220]
x2 = range(len(y2)) 
y3 = hrv[147:220]
x3 = range(len(y3)) 

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(6, 6))

ax1.plot(x1, y1, 'b-', label='Heart Rate Data')
ax1.set_xlabel('Time points (minutes)')
ax1.set_ylabel('Number of beats per minute', color='b')
ax1.tick_params('y', colors='b')
ax1.legend()

ax2.plot(x2, y2, 'r-', label='RR Data')
ax2.set_xlabel('Time points (minutes)')
ax2.set_ylabel('RR (ms)', color='r')
ax2.tick_params('y', colors='r')
ax2.legend()

ax3.plot(x3, y3, 'g-', label='HRV Data')
ax3.set_xlabel('Time points (minutes)')
ax3.set_ylabel('HRV (ms)', color='g')
ax3.tick_params('y', colors='g')
ax3.legend()

plt.suptitle('Heart Related Data')
plt.tight_layout()
plt.show()
